# %%
import pandas as pd 
from ultralytics import YOLO
import os

# %%
# Load the YOLOv8 model
model = YOLO("yolov8n.pt")  # "yolov8n.pt" is the smallest & fastest model

# Train the model on your dataset using CPU
model.train(data="D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\data.yaml", epochs=100, imgsz=640, device="cpu")  # 👈 Use "cpu"
# Out:
# New https://pypi.org/project/ultralytics/8.3.96 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.56  Python-3.11.5 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=train10, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train10
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\vinay\AppData\Roaming\Ultralytics\Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 1.08MB/s]
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753262  ultralytics.nn.modules.head.Detect           [10, [64, 128, 256]]
# Model summary: 225 layers, 3,012,798 parameters, 3,012,782 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\detect\train10', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\labels... 521 images, 34 backgrounds, 280 corrupt: 100%|██████████| 521/521 [00:00<00:00, 1441.74it/s]
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\-2297-_png_jpg.rf.180f5463b6a04f7a598d07b9911d8439.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\-2406-_png_jpg.rf.7269f85661b268c015a5ee54d6e69674.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\-2544-_png_jpg.rf.bbd424c2b9470ff20ff625ce05001689.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\001425_jpg.rf.ccdefc0e04ac537ea9695148b9cc40b3.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\003184_jpg.rf.350907e4e78ed835b42f0aca59001d5a.jpg: ignoring corrupt image/label: Label class 20 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\005139_jpg.rf.ff62a48c0bd4e5b5dff61809c162d3b2.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\005180_jpg.rf.1527ba2b6c2b201c89ce18a0c465308e.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\005239_jpg.rf.00dddb5a9aaecbeebe07e0499c4e59eb.jpg: ignoring corrupt image/label: Label class 22 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\005310_jpg.rf.779dd1802a50a32495b716c32a9a67d4.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\006118_jpg.rf.07a45c83f80fef659eb79d408e6fb3ec.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\006858_jpg.rf.14c55e59e342e104bffda6a89782b313.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\01094_jpg.rf.819e7badd4c14bd8fa9b3c016b011c2f.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\01261_jpg.rf.0b5e204406a5ab97806f3bdab521c211.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\1582_jpg.rf.8b84f97b1f8533efa9e8a72fc94aef27.jpg: ignoring corrupt image/label: Label class 16 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\2009_000280_jpg.rf.63b2c0c5a5cdc32a47063a3db6b7f671.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\2009_002711_jpg.rf.d6db8b16ba22736f732333bf0623acfe.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\2_jpg.rf.81284cfdb1490caf3a2d80f51ac535d1.jpg: ignoring corrupt image/label: Label class 15 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\2_jpg.rf.cd1c6c56f20c6305e180bba53b1bbeb1.jpg: ignoring corrupt image/label: Label class 24 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\494_jpg.rf.dba963e123cb1f6a5ddffc08694c2ec2.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\IMG_5847_jpg.rf.bf669e2a5d215e74dcbfb2bfce4a52b3.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\IMG_5848_jpg.rf.d0846722eeb9cb7a395e76ee16b1c8f0.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\IMG_5850_jpg.rf.a18d9493450262f17b13213d31ae0da9.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\IMG_5851_jpg.rf.aee5a5bfc33f7b33d134fd5731e0e8e7.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\Image_1009_jpg.rf.1a0460378951ab6f19998f995fcaf596.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\Image_1025_jpg.rf.7432f4f3791c827de09d797ecf02bef5.jpg: ignoring corrupt image/label: Label class 17 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\Image_991_jpg.rf.0bf2a874cd53c213995c1b8dd91d81d9.jpg: ignoring corrupt image/label: Label class 21 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\Image_995_jpg.rf.f8cbae851ef10024f96828a982035b47.jpg: ignoring corrupt image/label: Label class 24 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\amz_02354_png_jpg.rf.93ee089350f9f2eeac3d2aa9dd07121f.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\autox2_mp4-74_jpg.rf.f5b75e0280d384742aec68e91444e911.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\autox3_mp4-49_jpg.rf.4e6423d87131ffde751237b4dc2cbace.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\autox4_mp4-111_jpg.rf.e1f3676fab8297624586fce2d9b88431.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\autox4_mp4-112_jpg.rf.82ae728096c6fe9d9a4d55668ea2abfd.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\autox4_mp4-42_jpg.rf.863cf14a34c3f80d00878d2c0a35b04c.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\autox5_mp4-34_jpg.rf.8c18c362668ba8f0990280a4d60f5750.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# train: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\train\images\aut
jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-200_jpg.rf.2e18ca9e847a8153b4fb619a6dfb83de.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-226_jpg.rf.0ada36ea4b0c0bb257f4c15f4ef6ba23.jpg: ignoring corrupt image/label: Label class 24 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-226_jpg.rf.a3c0230b4f260db267ab0e27ddf771ef.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-255_jpg.rf.f2d5af947c40636a05fae7ed1ac5fe8d.jpg: ignoring corrupt image/label: Label class 20 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-260_jpg.rf.e167e42df17d90f2a976724e60d4ce70.jpg: ignoring corrupt image/label: Label class 24 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-267_jpg.rf.bf382a2f0c5b0249cdae278ee1b63c70.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-277_jpg.rf.7de843580b927e1b97aef1bf20310950.jpg: ignoring corrupt image/label: Label class 22 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-287_jpg.rf.586807564387d84ca3261cb587f0aa6e.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-342_jpg.rf.4c8e3a0e3b95069c5783ec67e75ec611.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-367_jpg.rf.8236c31ffa99d2b9e9cba79718e2700c.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-391_jpg.rf.941d2a1277953dea6f593a6f4a790a1f.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-392_jpg.rf.7ae8ad40bc5ce3b8b6f4354898cb9455.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-399_jpg.rf.74162836a5dc16bbe6fec0cb15c81002.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-405_jpg.rf.0fe0e494cf21c276c70e34b88b5ad6ca.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-416_jpg.rf.f42589f527210d4d488c5963090e0985.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-455_jpg.rf.b4a2bbd54738aa12b746d9934005477b.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-470_jpg.rf.e90d85e1707055ef808ad0e3c345fb1d.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-487_jpg.rf.7507d89df3b1f7cdbb12d073835ccf15.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-504_jpg.rf.f9a147e51e9c8da3cf7a2f6192350774.jpg: ignoring corrupt image/label: Label class 23 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-584_jpg.rf.f95e03ef7339db11bb74bcfd352d2a38.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-617_jpg.rf.0f5ea7ba0ae177b6428e831987a50f8b.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-619_jpg.rf.acaa28bf8879aa2ebc6330470d4eef72.jpg: ignoring corrupt image/label: Label class 11 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-697_jpg.rf.6f131cdcfc4849be0f93b59e4c0678c1.jpg: ignoring corrupt image/label: Label class 15 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-70_jpg.rf.d462e806dbde9dfeb66de4692ca6a168.jpg: ignoring corrupt image/label: Label class 13 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-727_jpg.rf.46d21066452c1e0dbb31b91f207653af.jpg: ignoring corrupt image/label: Label class 15 exceeds dataset class count 10. Possible class labels are 0-9
# val: WARNING  D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\images\youtube-836_jpg.rf.c95929820a1458bb5693dfdff28d47ca.jpg: ignoring corrupt image/label: Label class 22 exceeds dataset class count 10. Possible class labels are 0-9
# val: New cache created: D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\valid\labels.cache
# Plotting labels to runs\detect\train10\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train10
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/16 [00:11<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 5
#       2 model = YOLO("yolov8n.pt")  # "yolov8n.pt" is the smallest & fastest model
#       4 # Train the model on your dataset using CPU
# ----> 5 model.train(data="D:\#Safety Kit\Construction-Site-Safety-PPE-Detection\data\data.yaml", epochs=100, imgsz=640, device="cpu")  # 👈 Use "cpu"
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py:806, in Model.train(self, trainer, **kwargs)
#     803     self.model = self.trainer.model
#     805 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 806 self.trainer.train()
#     807 # Update model and cfg after training
#     808 if RANK in {-1, 0}:
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\trainer.py:207, in BaseTrainer.train(self)
#     204         ddp_cleanup(self, str(file))
#     206 else:
# --> 207     self._do_train(world_size)
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\trainer.py:380, in BaseTrainer._do_train(self, world_size)
#     378 with autocast(self.amp):
#     379     batch = self.preprocess_batch(batch)
# --> 380     self.loss, self.loss_items = self.model(batch)
#     381     if RANK != -1:
#     382         self.loss *= world_size
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\tasks.py:111, in BaseModel.forward(self, x, *args, **kwargs)
#      97 """
#      98 Perform forward pass of the model for either training or inference.
#      99
#    (...)
#     108     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     109 """
#     110 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 111     return self.loss(x, *args, **kwargs)
#     112 return self.predict(x, *args, **kwargs)
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\tasks.py:293, in BaseModel.loss(self, batch, preds)
#     290     self.criterion = self.init_criterion()
#     292 preds = self.forward(batch["img"]) if preds is None else preds
# --> 293 return self.criterion(preds, batch)
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\utils\loss.py:234, in v8DetectionLoss.__call__(self, preds, batch)
#     230 pred_bboxes = self.bbox_decode(anchor_points, pred_distri)  # xyxy, (b, h*w, 4)
#     231 # dfl_conf = pred_distri.view(batch_size, -1, 4, self.reg_max).detach().softmax(-1)
#     232 # dfl_conf = (dfl_conf.amax(-1).mean(-1) + dfl_conf.amax(-1).amin(-1)) / 2
# --> 234 _, target_bboxes, target_scores, fg_mask, _ = self.assigner(
#     235     # pred_scores.detach().sigmoid() * 0.8 + dfl_conf.unsqueeze(-1) * 0.2,
#     236     pred_scores.detach().sigmoid(),
#     237     (pred_bboxes.detach() * stride_tensor).type(gt_bboxes.dtype),
#     238     anchor_points * stride_tensor,
#     239     gt_labels,
#     240     gt_bboxes,
#     241     mask_gt,
#     242 )
#     244 target_scores_sum = max(target_scores.sum(), 1)
#     246 # Cls loss
#     247 # loss[1] = self.varifocal_loss(pred_scores, target_scores, target_labels) / target_scores_sum  # VFL way
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\utils\tal.py:74, in TaskAlignedAssigner.forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      65     return (
#      66         torch.full_like(pd_scores[..., 0], self.bg_idx),
#      67         torch.zeros_like(pd_bboxes),
#    (...)
#      70         torch.zeros_like(pd_scores[..., 0]),
#      71     )
#      73 try:
# ---> 74     return self._forward(pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      75 except torch.OutOfMemoryError:
#      76     # Move tensors to CPU, compute, then move back to original device
#      77     LOGGER.warning("WARNING: CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU")
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\utils\tal.py:102, in TaskAlignedAssigner._forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      82 def _forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt):
#      83     """
#      84     Compute the task-aligned assignment. Reference code is available at
#      85     https://github.com/Nioolek/PPYOLOE_pytorch/blob/master/ppyoloe/assigner/tal_assigner.py.
#    (...)
#     100         target_gt_idx (Tensor): shape(bs, num_total_anchors)
#     101     """
# --> 102     mask_pos, align_metric, overlaps = self.get_pos_mask(
#     103         pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt
#     104     )
#     106     target_gt_idx, fg_mask, mask_pos = self.select_highest_overlaps(mask_pos, overlaps, self.n_max_boxes)
#     108     # Assigned target
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\utils\tal.py:124, in TaskAlignedAssigner.get_pos_mask(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt)
#     122 mask_in_gts = self.select_candidates_in_gts(anc_points, gt_bboxes)
#     123 # Get anchor_align metric, (b, max_num_obj, h*w)
# --> 124 align_metric, overlaps = self.get_box_metrics(pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_in_gts * mask_gt)
#     125 # Get topk_metric mask, (b, max_num_obj, h*w)
#     126 mask_topk = self.select_topk_candidates(align_metric, topk_mask=mask_gt.expand(-1, -1, self.topk).bool())
#
# File c:\Users\vinay\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\utils\tal.py:143, in TaskAlignedAssigner.get_box_metrics(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_gt)
#     141 ind[1] = gt_labels.squeeze(-1)  # b, max_num_obj
#     142 # Get the scores of each grid for each gt cls
# --> 143 bbox_scores[mask_gt] = pd_scores[ind[0], :, ind[1]][mask_gt]  # b, max_num_obj, h*w
#     145 # (b, max_num_obj, 1, 4), (b, 1, h*w, 4)
#     146 pd_boxes = pd_bboxes.unsqueeze(1).expand(-1, self.n_max_boxes, -1, -1)[mask_gt]
#
# IndexError: index 10 is out of bounds for dimension 1 with size 10
